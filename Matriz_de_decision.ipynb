# %% [markdown]
# <a href="https://colab.research.google.com/github/JavaUroz/ProyectoFinalPP/blob/main/Matriz_de_decision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# Creamos el dataset con las valoraciones
data = pd.DataFrame()
data['Agencia']=['Agencia 1', 'Agencia 2', 'Agencia 3']
data['Precio'] = [5,3,1]
data['Experiencia'] = [2,4,5]
data['Comunicación'] = [3,2,3]
data['Valoracion_Clientes'] = [3,5,4]

# %%
# Revisamos el dataframe
data.head()
# Out:
#      Agencia  Precio  Experiencia  Comunicación  Valoracion_Clientes
# 0  Agencia 1       5            2             3                    3
# 1  Agencia 2       3            4             2                    5
# 2  Agencia 3       1            5             3                    4

# %%
#Puntuamos los criterios
Precio = 4
Experiencia = 5
Comunicación = 2
Valoracion_Clientes = 3

# %%
# Creamos la función de la matriz de decisión

def matriz_decisión(dataframe, precio, experiencia, comunicacion, valoracion):
  dataframe['Puntuacion']=dataframe['Precio']*precio+dataframe['Experiencia']*experiencia+dataframe['Comunicación']*comunicacion+dataframe['Valoracion_Clientes']*valoracion
  return dataframe

# %%
ponderacion = matriz_decisión(data, Precio, Experiencia, Comunicación, Valoracion_Clientes)
ponderacion
# Out:
#      Agencia  Precio  Experiencia  Comunicación  Valoracion_Clientes  \
# 0  Agencia 1       5            2             3                    3
# 1  Agencia 2       3            4             2                    5
# 2  Agencia 3       1            5             3                    4
#
#    Puntuacion
# 0          45
# 1          51
# 2          47

# %%
#Puntuamos los criterios en forma similar
Precio = 1 
Experiencia = 1
Comunicación = 1
Valoracion_Clientes = 1

# %%
ponderacion = matriz_decisión(data, Precio, Experiencia, Comunicación, Valoracion_Clientes)
ponderacion
# Out:
#      Agencia  Precio  Experiencia  Comunicación  Valoracion_Clientes  \
# 0  Agencia 1       5            2             3                    3
# 1  Agencia 2       3            4             2                    5
# 2  Agencia 3       1            5             3                    4
#
#    Puntuacion
# 0          13
# 1          14
# 2          13

# %%
# Importamos la libreria para acceder a los archivos en Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Importamos los datos desde Drive
vehiculos = pd.read_csv('DSS - Tablas de datos - Vehiculos.csv')
vehiculos.head(3)
# Out:
#         Marca  Modelo                                           Version  \
# 0  Volkswagen    Polo  1.6 MSi Trendline Tiptronic (110cv) (L18) 5Ptas.
# 1  Volkswagen    Polo       1.6 MSi Comfortline MT (110cv) (L18) 5Ptas.
# 2  Volkswagen  Amarok     2.0 TDI (180cv) 4x2 C/Doble Comfortline (L17)
#
#   TipoVehiculo Combustible  Potencia Transmisión Cabina Traccion Potencia.1  \
# 0     Sedan 5P       Nafta       110  Automática    NaN      4x2      MEDIO
# 1     Sedan 5P       Nafta       110      Manual    NaN      4x2      MEDIO
# 2    Camioneta      Diesel       180  Automática  Doble      4x2       ALTO
#
#   Consumo Seguridad  C  P  S
# 0   MEDIO      ALTO  2  2  3
# 1   MEDIO      ALTO  2  2  3
# 2    ALTO     MEDIO  3  3  2

# %%
# Importamos las librerias para poder realizar el codificado de las etiquetas - Convertir variables categóricas a numéricas
import numpy as np
from sklearn import preprocessing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [7], line 3
#       1 # Importamos las librerias para poder realizar el codificado de las etiquetas - Convertir variables categóricas a numéricas
#       2 import numpy as np
# ----> 3 from sklearn import preprocessing
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# Creamos el label encoder
le = preprocessing.LabelEncoder()

# %%
# Creamos un dataset alternativo para codificar.
encoded = vehiculos
encoded.head()
# Out:
#         Marca  Modelo                                           Version  \
# 0  Volskwagen    Polo  1.6 MSi Trendline Tiptronic (110cv) (L18) 5Ptas.
# 1  Volskwagen    Polo       1.6 MSi Comfortline MT (110cv) (L18) 5Ptas.
# 2  Volskwagen  Amarok     2.0 TDI (180cv) 4x2 C/Doble Comfortline (L17)
# 3  Volskwagen  Amarok     2.0 TDI (180cv) 4x4 C/Doble Comfortline (L17)
# 4  Volskwagen    Taos              Comfortline 250TSI Tiptronic (150cv)
#
#   TipoVehiculo Combustible  Potencia Transmisión Cabina Traccion Potencia.1  \
# 0     Sedan 5P       Nafta       110  Automática    NaN      4x2      MEDIO
# 1     Sedan 5P       Nafta       110      Manual    NaN      4x2      MEDIO
# 2    Camioneta      Diesel       180  Automática  Doble      4x2       ALTO
# 3    Camioneta      Diesel       180  Automática  Doble      4x4       ALTO
# 4          SUV       Nafta       150  Automática    NaN      4x2       ALTO
#
#   Consumo Seguridad
# 0   MEDIO      ALTO
# 1   MEDIO      ALTO
# 2    ALTO     MEDIO
# 3    ALTO     MEDIO
# 4    ALTO      ALTO

# %%
# Hacemos una primera prueba con la variable Potencia
encoded['C-Potencia']= le.fit_transform(encoded['Potencia.1'])
encoded.head()
# Out:
#         Marca  Modelo                                           Version  \
# 0  Volskwagen    Polo  1.6 MSi Trendline Tiptronic (110cv) (L18) 5Ptas.
# 1  Volskwagen    Polo       1.6 MSi Comfortline MT (110cv) (L18) 5Ptas.
# 2  Volskwagen  Amarok     2.0 TDI (180cv) 4x2 C/Doble Comfortline (L17)
# 3  Volskwagen  Amarok     2.0 TDI (180cv) 4x4 C/Doble Comfortline (L17)
# 4  Volskwagen    Taos              Comfortline 250TSI Tiptronic (150cv)
#
#   TipoVehiculo Combustible  Potencia Transmisión Cabina Traccion Potencia.1  \
# 0     Sedan 5P       Nafta       110  Automática    NaN      4x2      MEDIO
# 1     Sedan 5P       Nafta       110      Manual    NaN      4x2      MEDIO
# 2    Camioneta      Diesel       180  Automática  Doble      4x2       ALTO
# 3    Camioneta      Diesel       180  Automática  Doble      4x4       ALTO
# 4          SUV       Nafta       150  Automática    NaN      4x2       ALTO
#
#   Consumo Seguridad  C-Potencia
# 0   MEDIO      ALTO           2
# 1   MEDIO      ALTO           2
# 2    ALTO     MEDIO           0
# 3    ALTO     MEDIO           0
# 4    ALTO      ALTO           0

# %%
le.classes_
# Out:
# array(['ALTO', 'BAJO', 'MEDIO'], dtype=object)

# %%
# Modificamos las clases del encoder para que reflejen correctamente la variable ordinal
le.classes_ = np.array(['BAJO','MEDIO','ALTO'])

# %%
encoded['C-Potencia']= le.transform(encoded['Potencia.1'])
encoded['C-Consumo']= le.transform(encoded['Consumo'])
encoded['C-Seguridad']= le.transform(encoded['Seguridad'])
encoded.head(10)
# Out:
#         Marca       Modelo                                           Version  \
# 0  Volskwagen         Polo  1.6 MSi Trendline Tiptronic (110cv) (L18) 5Ptas.
# 1  Volskwagen         Polo       1.6 MSi Comfortline MT (110cv) (L18) 5Ptas.
# 2  Volskwagen       Amarok     2.0 TDI (180cv) 4x2 C/Doble Comfortline (L17)
# 3  Volskwagen       Amarok     2.0 TDI (180cv) 4x4 C/Doble Comfortline (L17)
# 4  Volskwagen         Taos              Comfortline 250TSI Tiptronic (150cv)
# 5        Ford  EcoSport KD                           1.5 SE MT (123cv) (L18)
# 6        Ford       Ranger         2.2 TDCi C/Doble 4x2 XL 6MT (125cv) (L20)
# 7        Ford       Ranger        2.2 TDCi C/Simple 4x2 XL 6MT (125cv) (L20)
# 8        Fiat         Mobi                                   1.0 Like (75cv)
# 9        Fiat       Cronos                      1.3 GSE CVT Presicion (99cv)
#
#   TipoVehiculo Combustible  Potencia Transmisión  Cabina Traccion Potencia.1  \
# 0     Sedan 5P       Nafta       110  Automática     NaN      4x2      MEDIO
# 1     Sedan 5P       Nafta       110      Manual     NaN      4x2      MEDIO
# 2    Camioneta      Diesel       180  Automática   Doble      4x2       ALTO
# 3    Camioneta      Diesel       180  Automática   Doble      4x4       ALTO
# 4          SUV       Nafta       150  Automática     NaN      4x2       ALTO
# 5          SUV       Nafta       123      Manual     NaN      4x2      MEDIO
# 6    Camioneta      Diesel       125      Manual   Doble      4x2      MEDIO
# 7    Camioneta      Diesel       125      Manual  Simple      4x2      MEDIO
# 8     Sedan 5P       Nafta        75      Manual     NaN      4x2       BAJO
# 9     Sedan 5P       Nafta        99  Automática     NaN      4x2       BAJO
#
#   Consumo Seguridad  C-Potencia  C-Consumo  C-Seguridad
# 0   MEDIO      ALTO           1          1            2
# 1   MEDIO      ALTO           1          1            2
# 2    ALTO     MEDIO           2          2            1
# 3    ALTO     MEDIO           2          2            1
# 4    ALTO      ALTO           2          2            2
# 5   MEDIO      ALTO           1          1            2
# 6   MEDIO     MEDIO           1          1            1
# 7   MEDIO     MEDIO           1          1            1
# 8    BAJO      BAJO           0          0            0
# 9    BAJO      BAJO           0          0            0

# %%
# Creamos la función de la matriz de decisión
def matriz_decisión(dataframe, consumo, potencia,seguridad):
  dataframe['Puntuacion']=(dataframe['C-Consumo']*(1-consumo)+1)+(dataframe['C-Potencia']*potencia+1)+(dataframe['C-Seguridad']*seguridad)
  return dataframe

# %%
# Puntuamos los criterio para ponderar las preferencias
Consumo = 3
Potencia = 2
Seguridad = 5

# %%
ponderacion = matriz_decisión(encoded, Consumo, Potencia, Seguridad)
ponderacion
# Out:
#          Marca         Modelo  \
# 0   Volskwagen           Polo
# 1   Volskwagen           Polo
# 2   Volskwagen         Amarok
# 3   Volskwagen         Amarok
# 4   Volskwagen           Taos
# 5         Ford    EcoSport KD
# 6         Ford         Ranger
# 7         Ford         Ranger
# 8         Fiat           Mobi
# 9         Fiat         Cronos
# 10        Fiat          Pulse
# 11        Fiat           Toro
# 12      Toyota  Corolla Cross
# 13      Toyota  Corolla Cross
# 14      Toyota        Corolla
# 15      Toyota          Etios
# 16      Toyota          Hilux
# 17      Toyota          Hilux
#
#                                              Version TipoVehiculo Combustible  \
# 0   1.6 MSi Trendline Tiptronic (110cv) (L18) 5Ptas.     Sedan 5P       Nafta
# 1        1.6 MSi Comfortline MT (110cv) (L18) 5Ptas.     Sedan 5P       Nafta
# 2      2.0 TDI (180cv) 4x2 C/Doble Comfortline (L17)    Camioneta      Diesel
# 3      2.0 TDI (180cv) 4x4 C/Doble Comfortline (L17)    Camioneta      Diesel
# 4               Comfortline 250TSI Tiptronic (150cv)          SUV       Nafta
# 5                            1.5 SE MT (123cv) (L18)          SUV       Nafta
# 6          2.2 TDCi C/Doble 4x2 XL 6MT (125cv) (L20)    Camioneta      Diesel
# 7         2.2 TDCi C/Simple 4x2 XL 6MT (125cv) (L20)    Camioneta      Diesel
# 8                                    1.0 Like (75cv)     Sedan 5P       Nafta
# 9                       1.3 GSE CVT Presicion (99cv)     Sedan 5P       Nafta
# 10                          1.0T Impetus CVT (130cv)     Sedan 5P       Nafta
# 11       1.8 Freedom 4x2 AT6 Cab/Doble (130cv) (L21)    Camioneta       Nafta
# 12                                       2.0 XEI CVT          SUV       Nafta
# 13                                  HEV 1.8 SEG eCVT          SUV     Híbrido
# 14                         2.0 SEG CVT (170cv) (L20)     Sedan 5P       Nafta
# 15                    1.5 X 6MT (105cv) (L18) 4Ptas.     Sedan 5P       Nafta
# 16               4x2 CD DX 2.4 TDI 6MT (150cv) (L20)    Camioneta      Diesel
# 17               4x4 CD DX 2.4 TDI 6MT (150cv) (L20)    Camioneta      Diesel
#
#     Potencia Transmisión  Cabina Traccion Potencia.1 Consumo Seguridad  \
# 0        110  Automática     NaN      4x2      MEDIO   MEDIO      ALTO
# 1        110      Manual     NaN      4x2      MEDIO   MEDIO      ALTO
# 2        180  Automática   Doble      4x2       ALTO    ALTO     MEDIO
# 3        180  Automática   Doble      4x4       ALTO    ALTO     MEDIO
# 4        150  Automática     NaN      4x2       ALTO    ALTO      ALTO
# 5        123      Manual     NaN      4x2      MEDIO   MEDIO      ALTO
# 6        125      Manual   Doble      4x2      MEDIO   MEDIO     MEDIO
# 7        125      Manual  Simple      4x2      MEDIO   MEDIO     MEDIO
# 8         75      Manual     NaN      4x2       BAJO    BAJO      BAJO
# 9         99  Automática     NaN      4x2       BAJO    BAJO      BAJO
# 10       130  Automática     NaN      4x2      MEDIO   MEDIO      BAJO
# 11       130  Automática     NaN      4x2      MEDIO   MEDIO      BAJO
# 12       170  Automática     NaN      4x4       ALTO    ALTO      ALTO
# 13       132  Automática     NaN      4x2      MEDIO    BAJO      ALTO
# 14       170  Automática     NaN      4x2       ALTO    ALTO      ALTO
# 15       105      Manual     NaN      4x2      MEDIO   MEDIO     MEDIO
# 16       150      Manual   Doble      4x2       ALTO    ALTO      ALTO
# 17       150      Manual   Doble      4x4       ALTO    ALTO      ALTO
#
#     C-Potencia  C-Consumo  C-Seguridad  Puntuacion
# 0            1          1            2          12
# 1            1          1            2          12
# 2            2          2            1           7
# 3            2          2            1           7
# 4            2          2            2          12
# 5            1          1            2          12
# 6            1          1            1           7
# 7            1          1            1           7
# 8            0          0            0           2
# 9            0          0            0           2
# 10           1          1            0           2
# 11           1          1            0           2
# 12           2          2            2          12
# 13           1          0            2          14
# 14           2          2            2          12
# 15           1          1            1           7
# 16           2          2            2          12
# 17           2          2            2          12

# %%
# 
ponderacion.sort_values(by='Puntuacion', ascending=False)
# Out:
#          Marca         Modelo  \
# 13      Toyota  Corolla Cross
# 0   Volskwagen           Polo
# 1   Volskwagen           Polo
# 16      Toyota          Hilux
# 14      Toyota        Corolla
# 12      Toyota  Corolla Cross
# 17      Toyota          Hilux
# 5         Ford    EcoSport KD
# 4   Volskwagen           Taos
# 7         Ford         Ranger
# 6         Ford         Ranger
# 3   Volskwagen         Amarok
# 15      Toyota          Etios
# 2   Volskwagen         Amarok
# 8         Fiat           Mobi
# 10        Fiat          Pulse
# 11        Fiat           Toro
# 9         Fiat         Cronos
#
#                                              Version TipoVehiculo Combustible  \
# 13                                  HEV 1.8 SEG eCVT          SUV     Híbrido
# 0   1.6 MSi Trendline Tiptronic (110cv) (L18) 5Ptas.     Sedan 5P       Nafta
# 1        1.6 MSi Comfortline MT (110cv) (L18) 5Ptas.     Sedan 5P       Nafta
# 16               4x2 CD DX 2.4 TDI 6MT (150cv) (L20)    Camioneta      Diesel
# 14                         2.0 SEG CVT (170cv) (L20)     Sedan 5P       Nafta
# 12                                       2.0 XEI CVT          SUV       Nafta
# 17               4x4 CD DX 2.4 TDI 6MT (150cv) (L20)    Camioneta      Diesel
# 5                            1.5 SE MT (123cv) (L18)          SUV       Nafta
# 4               Comfortline 250TSI Tiptronic (150cv)          SUV       Nafta
# 7         2.2 TDCi C/Simple 4x2 XL 6MT (125cv) (L20)    Camioneta      Diesel
# 6          2.2 TDCi C/Doble 4x2 XL 6MT (125cv) (L20)    Camioneta      Diesel
# 3      2.0 TDI (180cv) 4x4 C/Doble Comfortline (L17)    Camioneta      Diesel
# 15                    1.5 X 6MT (105cv) (L18) 4Ptas.     Sedan 5P       Nafta
# 2      2.0 TDI (180cv) 4x2 C/Doble Comfortline (L17)    Camioneta      Diesel
# 8                                    1.0 Like (75cv)     Sedan 5P       Nafta
# 10                          1.0T Impetus CVT (130cv)     Sedan 5P       Nafta
# 11       1.8 Freedom 4x2 AT6 Cab/Doble (130cv) (L21)    Camioneta       Nafta
# 9                       1.3 GSE CVT Presicion (99cv)     Sedan 5P       Nafta
#
#     Potencia Transmisión  Cabina Traccion Potencia.1 Consumo Seguridad  \
# 13       132  Automática     NaN      4x2      MEDIO    BAJO      ALTO
# 0        110  Automática     NaN      4x2      MEDIO   MEDIO      ALTO
# 1        110      Manual     NaN      4x2      MEDIO   MEDIO      ALTO
# 16       150      Manual   Doble      4x2       ALTO    ALTO      ALTO
# 14       170  Automática     NaN      4x2       ALTO    ALTO      ALTO
# 12       170  Automática     NaN      4x4       ALTO    ALTO      ALTO
# 17       150      Manual   Doble      4x4       ALTO    ALTO      ALTO
# 5        123      Manual     NaN      4x2      MEDIO   MEDIO      ALTO
# 4        150  Automática     NaN      4x2       ALTO    ALTO      ALTO
# 7        125      Manual  Simple      4x2      MEDIO   MEDIO     MEDIO
# 6        125      Manual   Doble      4x2      MEDIO   MEDIO     MEDIO
# 3        180  Automática   Doble      4x4       ALTO    ALTO     MEDIO
# 15       105      Manual     NaN      4x2      MEDIO   MEDIO     MEDIO
# 2        180  Automática   Doble      4x2       ALTO    ALTO     MEDIO
# 8         75      Manual     NaN      4x2       BAJO    BAJO      BAJO
# 10       130  Automática     NaN      4x2      MEDIO   MEDIO      BAJO
# 11       130  Automática     NaN      4x2      MEDIO   MEDIO      BAJO
# 9         99  Automática     NaN      4x2       BAJO    BAJO      BAJO
#
#     C-Potencia  C-Consumo  C-Seguridad  Puntuacion
# 13           1          0            2          14
# 0            1          1            2          12
# 1            1          1            2          12
# 16           2          2            2          12
# 14           2          2            2          12
# 12           2          2            2          12
# 17           2          2            2          12
# 5            1          1            2          12
# 4            2          2            2          12
# 7            1          1            1           7
# 6            1          1            1           7
# 3            2          2            1           7
# 15           1          1            1           7
# 2            2          2            1           7
# 8            0          0            0           2
# 10           1          1            0           2
# 11           1          1            0           2
# 9            0          0            0           2

# %%
encoded.to_csv('vehiculos.csv')
